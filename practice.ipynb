# %%
fruits = ['사과', '바나나', '오렌지', '포도', '수박']
print('과일가게에 오신 것을 환영합니다!')
print(f'오늘 판매하는과일{fruits}')
stop = '그만'
apple = 3
banana = 3
orange = 3
grape = 3
waterme = 3

while True:
    print(f'현재재고:사과: {apple}, 바나나: {banana}, 오렌지: {orange}, 포도: {grape}, 수박: {waterme}')
    input_fruits = input('어떤 과일을 구매하시겠습니까? (종료하려면 "그만"을 입력하세요)')
    if input_fruits == '그만':
        break
    elif input_fruits == '사과' and apple >= 0 :
        if apple == 0 :
            print('사과는 모두 품절되었습니다 다른 과일을 골라주세요')
            continue
        apple -= 1
        print(f'사과을(를) 구매하셨습니다! 남은 사과의 재고 :{apple}')
    elif input_fruits == '바나나' and banana >=0 :
        if banana == 0 :
            print('바나나는 모두 품절되었습니다 다른 과일을 골라주세요')
            continue
        banana -= 1
        print(f'바나나을(를) 구매하셨습니다! 남은 바나나의 재고 :{banana}')
    elif input_fruits == '오렌지' and orange >=0 :
        if orange == 0 :
            print('오렌지는 모두 품절되었습니다 다른 과일을 골라주세요')
            continue
        orange -= 1
        print(f'오렌지을(를) 구매하셨습니다! 남은 오렌지의 재고 :{orange}')
    elif input_fruits == '포도' and grape >=0 :
        if grape == 0 :
            print('포도는 모두 품절되었습니다 다른 과일을 골라주세요')
            continue
        grape -= 1
        print(f'포도을(를) 구매하셨습니다! 남은 포도의 재고 :{grape}')
    elif input_fruits == '수박'and waterme >=0 :
        if waterme == 0 :
            print('수박은 모두 품절되었습니다 다른 과일을 골라주세요')
            continue
        grape -= 1
        print(f'수박을(를) 구매하셨습니다! 남은 수박의 재고 :{waterme}')
    elif apple+banana+orange+grape+waterme == 0 :
            print('모든 과일이 다 팔렸습니다. 가게를 종료합니다.')
            break

# %% [markdown]
# # 리스트 (immutable)

# %%
a = [1,2,3,4,5,7]
print(a[2]+a[5])

# 리스트 함수들*********************************************************************************************
lst = [3, 1, 4, 2]
lst.append(5)        # [3, 1, 4, 2, 5]
lst.extend([6, 7])   # [3, 1, 4, 2, 5, 6, 7]
lst.insert(1, 10)    # [3, 10, 1, 4, 2, 5, 6, 7]
lst.remove(10)       # [3, 1, 4, 2, 5, 6, 7]
lst.sort()           # [1, 2, 3, 4, 5, 6, 7]
lst.reverse()        # [7, 6, 5, 4, 3, 2, 1]
lst.index(4)  # 3
lst.count(2)  # 1
len(lst)  # 4
sum(lst)  # 10
max(lst)  # 4
min(lst)  # 1
2 in lst  # True
5 in lst  # False


a[1]=4
print(a)

del a[1]
print(a)
a.append(9)
a.insert(0,10)

sorted(a, key=lambda x:x>5, reverse=True)       # 5초과인 숫자만 정렬하겠음 나머지는 디폴트값 정렬렬
# 핵심 요약
# key에 함수(또는 람다 함수)를 전달하면, 각 요소가 정렬되기 전에 해당 함수의 반환값을 기준으로 정렬됩니다.
# reverse를 추가하면 정렬 순서를 반대로 변경할 수 있습니다.
# sorted()와 함께 key 매개변수를 사용하면 다양한 복잡한 정렬 작업도 쉽게 처리할 수 있습니다! 😊
# 예시
names = ["Alice", "Bob", "Charlie", "Dave"]
result = sorted(names, key=len)
print(result)  # ['Bob', 'Dave', 'Alice', 'Charlie']

data = [(1, 3), (4, 1), (2, 2)]
result = sorted(data, key=lambda x: x[1])
print(result)  # [(4, 1), (2, 2), (1, 3)]

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

people = [Person("Alice", 30), Person("Bob", 25), Person("Charlie", 35)]
result = sorted(people, key=lambda p: p.age)
print([p.name for p in result])  # ['Bob', 'Alice', 'Charlie']

# %%
a = [1, 2, 3, 4, 5, 6, 7, 8, 9]
a.extend([3,6])     # iterable 객체만 넣을 수 있음 / 2개 객체는 못넣음

# 대표적인 이터러블 객체들

# 리스트 (list)
# 튜플 (tuple)
# 문자열 (str)
# 딕셔너리 (dict)

a.append([3,4])
a.append((7,8))
a.append('사과')     # 2개 객체는 못넣음

print(a)
# **************************************************************************************
# mutable
# 리스트
# 딕셔너리
# 집합

# immutable
# 정수
# 실수
# 문자열
# 튜플플

a = {'qwdd':1}
a['ssadsa']='pay'
a['hhhh']=[1, 2, 3, 4, 5]
a['hhhh']=[66, 33, 77, 11]
a[(45,22)]='number'     # 키값으로 튜플도 들어감
# a[['tired, happy']]='number'    #키값이 리스트는 안들어감 = mutable자료이기때문에에
print(a)
print(a['ssadsa'])

print(a.keys)       # 변수의 주소만 나타냄
print(a.keys())     # 메모리를 덜차지하게하기 위해서 dict_keys로 나옴

# %% [markdown]
# # 딕셔너리 (mutable)

# %%
#
print(list(a.keys()))

# 딕셔너리 생성 방법
# 1. 중괄호 {} 사용

my_dict = {"name": "Alice", "age": 25}
# 2. dict() 함수 사용

my_dict = dict(name="Alice", age=25)

# 딕셔너리 메서드****************************************************************************************************
# keys(): 모든 키 반환
# values(): 모든 값 반환
# items(): (키, 값) 쌍을 반환
# update(): 딕셔너리 병합

my_dict = {"name": "Alice", "age": 25}
my_dict.keys()     # dict_keys(['name', 'age'])
my_dict.values()   # dict_values(['Alice', 25])
my_dict.items()    # dict_items([('name', 'Alice'), ('age', 25)])
my_dict.get('name') # 'Alice' ==> get을 쓰는 이유는 딕셔너리 외에 값이 들어가면 오류가 안뜨게 하기위해서 = None이 뜸뜸
my_dict.get('sdfkhllsdf', '없는 키값입니다')    # 결과값이 None일때 , 이후에 나오는것을 리턴함
'name' in my_dict   # True



# 기본 문법
# dict.update([other])
# other: 업데이트할 대상. 딕셔너리 또는 키-값 쌍(iterable)을 전달할 수 있습니다.
# 반환값: None (원본 딕셔너리를 직접 수정합니다).
# 사용 예제
# 1. 다른 딕셔너리 병합

dict1 = {"a": 1, "b": 2}
dict2 = {"b": 3, "c": 4}

dict1.update(dict2)
print(dict1)  # {'a': 1, 'b': 3, 'c': 4}
# dict2의 내용을 dict1에 병합합니다.
# 키 b의 값이 2에서 3으로 덮어씌워졌습니다.

# 리스트나 튜플로 전달
# update()는 키-값 쌍을 담은 iterable(리스트, 튜플 등)을 받을 수도 있습니다.

dict1 = {"a": 1}
dict1.update([("b", 2), ("c", 3)])
print(dict1)  # {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# # 집합 (mutable)

# %%
# set의 특징
# 중복을 허용하지 않음: 동일한 값이 여러 번 추가되더라도 하나의 값만 저장됩니다.
# 순서가 없음: 인덱스로 접근할 수 없습니다.
# 값들이 무작위 순서로 저장됩니다.
# 변경 가능(mutable): 요소를 추가하거나 삭제할 수 있습니다.
# 해시 가능한 값만 저장 가능: 리스트나 딕셔너리처럼 변경 가능한 객체는 저장할 수 없습니다.

# 기본 생성
my_set = {1, 2, 3}
print(my_set)  # {1, 2, 3}
my_set = set('Hello')   # {'o', 'e', 'H', 'l'}
# 이터러블(iterable)을 받아서 집합 생성.
my_set = set([1, 2, 2, 3])
print(my_set)  # {1, 2, 3}

# *****************************************************************************************************************
my_set = {1, 2, 3}
my_set.add(4)   # {1, 2, 3, 4} / add(x): 집합에 값 x를 추가. / 객체 한개만 가능
my_set.update([2, 3, 4])    # {1, 2, 3, 4} / update(iterable): 이터러블의 모든 요소를 집합에 추가.
my_set.remove(2)    # {1, 3, 4}] / remove(x): 값 x를 삭제. 값이 없으면 KeyError.
my_set.discard(4)  # 에러 없음 / discard(x): 값 x를 삭제. 값이 없으면 에러 발생하지 않음.
removed = my_set.pop() # 임의의의 값 출력력 pop(): 임의의 요소를 제거하고 반환.
print(my_set)   # pop하고 나머지 값 출력
my_set.clear()  # set() 모든 요소 제거.

set1 = {1, 2, 3}
set2 = {3, 4, 5}
set1 & set2   # {3}
set1.intersection(set2)  # {3}
set1 | set2  # {1, 2, 3, 4, 5} / set1 + set2
set1.union(set2)  # {1, 2, 3, 4, 5} / set1 + set2
set1.difference(set2)  # {1, 2} / set1 - set2
set1 - set2     # {1, 2} / set1 - set2

# %% [markdown]
# # 불 자료형

# %%
# "python"	참
# ""	        거짓
# [1, 2, 3]	참
# []	        거짓
# (1, 2, 3)	참
# ()	        거짓
# {'a': 1}	참
# {}	        거짓
# 1	        참
# 0	        거짓
# None	    거짓

# %% [markdown]
# # 변수란?

# %%
# a = [1, 2, 3]이라고 하면 [1, 2, 3] 값을 가지는 리스트 데이터(객체)가 자동으로 메모리에 생성되고 변수 a는 [1, 2, 3] 리스트가 저장된 메모리의 주소를 가리키게 된다.

a = [1, 2, 3]
id(a) => 4303029896
# id는 변수가 가리키고 있는 객체의 주소 값을 리턴하는 파이썬의 내장 함수이다. 
# 즉, 여기에서 필자가 만든 변수 a가 가리키는 [1, 2, 3] 리스트의 주소 값은 4303029896이라는 것을 알 수 있다.

a = [1, 2, 3]
b = a

id(a)
4303029896
id(b)
4303029896

a is b  # a와 b가 가리키는 객체가 같을까?
True

#b 변수를 생성할 때 a 변수의 값을 가져오면서 a와는 다른 주소를 가리키도록 만들 수는 없을까? 다음 2가지 방법이 있다.

# 1. [:] 이용하기 (슬라이싱)
a = [1, 2, 3]
b = a[:]
a[1] = 4
print(a)    # [1, 4, 3]
print(b)    # [1, 2, 3]

# 2. copy 모듈 이용하기
from copy import copy
a = [1, 2, 3]
b = copy(a)
b = a.copy()

# ===> b is a = False ***********************************************************************************

# 변수를 만드는 여러 가지 방법

# 다음과 같이 튜플로 a, b에 값을 대입할 수 있다.

a, b = ('python', 'life')
# 이 방법은 다음 예문과 완전히 동일하다.

(a, b) = 'python', 'life'
# 튜플 부분에서도 언급했지만, 튜플은 괄호를 생략해도 된다.

[a, b] = ['python', 'life']
# 또한 여러 개의 변수에 같은 값을 대입할 수도 있다.

a = b = 'python'
# 파이썬에서는 위 방법을 사용하여 두 변수의 값을 매우 간단하게 바꿀 수 있다.

a = 3
b = 5       # a 에 5를 담고 b에 3을 담고싶을때,
a, b = b, a

# %% [markdown]
# # 조건문 if문

# %%
if 조건식:  # 조건식이 False면 else로 감,
    수행할문장    # 조건식이 True면 밑으로감(elif) 
else:       # : 와 들여쓰기 중요함
    수행할문장

# 조건문에 비교 연산자(<, >, ==, !=, >=, <=)로 True, False 를 판단함

x or y	#x와 y 둘 중 하나만 참이어도 참이다.
x and y	#x와 y 모두 참이어야 참이다.
not x	#x가 거짓이면 참이다.

x in 리스트     # x가 리스트에 있는지,
x in 튜플       # x가 튜플에 있는지,
x in 문자열     # x가 문자열에 있는지,

# 조건문 수행할 문장에 아무것도 하고싶지 않다면?
pass 넣어주기

# %% [markdown]
# # 반복문 while 문

# %%
# while 조건문:
#     수행할_문장1
#     수행할_문장2
#     수행할_문장3
#     ...


        # 반복문 중지하기
coffee = 10
money = 300
while money:
    print("돈을 받았으니 커피를 줍니다.")
    coffee = coffee -1
    print("남은 커피의 양은 %d개입니다." % coffee)
    if coffee == 0:
        print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
        break


        # 반복문 처음으로 돌아가기, 조건에 맞지않으면 완전히 나가게됨
a = 0
while a < 10:
    a = a + 1
    if a % 2 == 0: continue
    print(a)

# %% [markdown]
# # for 문

# %%
# for 변수 in 이터러블(문자열, 튜플, 리스트, range(정수)):
#     수행할_문장1
#     수행할_문장2
#     ...

a = [(1,2), (3,4), (5,6)]
for (first, last) in a:
    print(first + last)


# continue 사용할때
marks = [90, 25, 67, 45, 80]

number = 0 
for mark in marks: 
    number = number +1 
    if mark < 60:
        continue 
    print("%d번 학생 축하합니다. 합격입니다. " % number)


# 구구단 만들기

for i in range(2,10):        # 1번 for문
    for j in range(1, 10):   # 2번 for문
        print(i*j, end=" ") 
    print('')

# %% [markdown]
# # 함수

# %%
# def 함수_이름(매개변수):      ** 매개변수 정말 중요함!!!!!!!!!!!!
#     수행할_문장1
#     수행할_문장2

# 1. 매개변수가 없는경우
# 2. 결과값이 없는경우

def say():
    print('hi')
a = say()
print(a)

>>> def add_mul(choice, *args): 
...     if choice == "add":   # 매개변수 choice에 "add"를 입력받았을 때
...         result = 0 
...         for i in args: 
...             result = result + i 
...     elif choice == "mul":   # 매개변수 choice에 "mul"을 입력받았을 때
...         result = 1 
...         for i in args: 
...             result = result * i 
...     return result

# %%
a = 4
def abc(a):
    a = a + 1
    return a        

print(abc(a))       # 새로운 주소로 만듬
a = abc(a)      # a에 반영하기 위해선 a의 주소에 넣어야함
print(a)        # 이전에 a 주소에 넣어서 반영됨

# b = [11,12,13,14,15]
# def vartest_1(b):
#     b = b.append(16)
b = [1,2,3,4,5]
vartest_1 = lambda b : b.append(16)
# 함수이름       매개변수 :  매개변수를 변경할 식
print(vartest_1(b))        # 함수의 리턴값이 없음
print(b)            # 리스트는 변경이 가능해서 함수에 의해 b 자체가 변경이됨(리턴값은 없지만)


d = [1,2,3,4,5]

print(d.append(6))
print(d)

# %% [markdown]
# # 판다스

# %%
import pandas as pd
from pandas import Series

# %% [markdown]
# ## 시리즈 사용법

# %%
arr = [1,2,3,4,5,6,7]
s = pd.Series(arr)
print(type(s))

data = [100,200,300]
index = ['월', '화', '수']
s_1 = pd.Series(data, index)
print(s_1)

print(s_1.iloc[0])        # 인덱싱 하는방법, 행번호로 인덱싱하기
print(s_1.iloc[-1])

print(s_1.loc['월'])
print(s_1.loc['화'])

sr_2 = [1,2,3,45,6,7,4]
index_1 = ['월','화','수','목','금','토','일']
s_1 = pd.Series(sr_2, index_1)
s_1.loc['월'] = 100     # 원본 수정됨,
s_1.loc['추가함'] = 123     # 원본 추가됨,
drop_1 = s_1.drop(['수','목','금'])      # 원본은 삭제안됨, / , inplace=True 이거를 쓰면 원본 삭제됨
print(drop_1)
print(s_1)

# %%
sr_3 = [1,2,3,45,6,7,4]
sr_4 = [9,7,6,5,3,2,2]
index_2 = ['월','화','수','목','금','토','일']
s_2 = pd.Series(sr_3, index_2)
s_3 = pd.Series(sr_4, index_2)
print(s_2 + 10)
print(s_2 - s_3)
print(s_2 == 5)
print(s_2 > s_3)

# %%
sr_4 = [100,200,300,440,500,600,700]        # 데이터
aaa_1 = pd.Series(sr_4)     # 데이터를 시리즈타입으로 변형
cond_1 = aaa_1 > 400        # 시리즈의 데이터를 필터링함
print(cond_1)       # 필터링한 결과값
print(aaa_1[cond_1])        # 결과값에 맞게 시리즈에서 골라냄

# %%
# 연습문제

low_price = pd.Series([10,200,200,400,600])
high_price = pd.Series([100,300,400,500,600])
filter_1 = high_price - low_price >= 100

print(high_price[filter_1])


end_price = pd.Series([93000,82400,99100,81000,72300],['05/14','05/15','05/16','05/17','05/18'])    # 밸류,인덱스 순으로 입력된거임임
condition_1 = (end_price >= 80000) & (end_price < 90000)        # and = & / or = | / not = ~ 써서 비교연산해야함함
print(end_price[condition_1])
print(end_price.loc['05/16'])       # 날짜는 인덱스로 들어간것을 알 수 있음음
# Out:
# 1    300
# 2    400
# 3    500
# dtype: int64
# 05/15    82400
# 05/17    81000
# dtype: int64
# 99100

# %%
# 시리즈는 1차원 데이터
# 데이터 프레임은 2차원 데이터임

# %%
df_1 = pd.DataFrame([['부산','001',123456],['서울','002',123145],['강원도','003',654322]])
#변수 =이 부분 대문자 필수/ ([]) 이런형태로 되어야함
print(df_1)
print('*'*40)
print(df_1.iloc[1,1])
print(df_1.iloc[:2,1])
print(df_1.iloc[1:,1:3])
