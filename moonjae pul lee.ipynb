# %%
# print('hello world')

# print('Mary\'s cosmetics')

# print('신씨가 소리질렀다, "도둑이야"')

# print('c:\\windows')

# print('naver', 'kakao', 'sk', 'samsung', sep=';')

# print('naver', 'sk', 'kakao', 'samsung', sep='/')

# print("first", end='');print("second")

# print(5/3)

# 삼성전자 = 50000

# # print(f'{삼성전자:, * 10}') # 기본적으로 파이선 코드해석은 왼쪽 -> 오른쪽 순으로 하기때문에, 중간에 문자열오류가 있으면 해석을 못함 / :, 다음에 *10 이 있어서!
# print(f'{삼성전자 * 10:,}')

# num_1 = "1231545"
# print(type(int(num_1)))

# num_2 = 123562344
# print(type(str(num_2)))

# num_3 = "12345.1235"
# print(type(float(num_3)))

# year = "2020"

# print(f'{int(year)-1}, {int(year)}, {int(year)+1}, {int(year)+2}')

# i_1 = 1           # 매월 할부금 이자 1% 붙으며 36개월까지 내야할 총 금액
# won_1 = 48584
# won_2 = 0

# while i_1 <= 36:
#     won_1 *= 1.01
#     won_2 += won_1
#     print(f'{won_2:,.3f}')
#     i_1 += 1

# i_2 = 1
# won_3 = 48584
# won_4 = 1

# while i_2 <= 36:
#     won_4 = won_3 * i_2
#     i_2 += 1
#     print(f'{won_4:,}')

# license_plate = '24가 2210'

# print(license_plate[4:])


# string_1 = "홀짝홀짝홀짝홀짝"

# print(string_1[0::2])


# string_2 = "python"

# print(string_2[::-1])


# phone_number = '010-1111-2222'
# phone_number1 = phone_number.replace('-', ' ')
# print(phone_number1)
# print(phone_number1, )

# url = "http://sharebook.kr"
# url_split = url.split('.')
# print(url_split[-1])


# string_3 = 'sdfOOIHgiufgKIUGHIUHLLIJSDiosjfoijdsfsdfoighs'
# string_4 = string_3.replace('s', 'S')
# print(string_4)

# t1 = "python"
# t2 = "java"
# t3 = t1 + t2
# print(t3 * 4)


# number_1 = "5,969,782,550"
# number_2 = number_1.replace(",", "")        # 문자열은 이뮤터블자료 이기때문에 리플레이스를 하면 문자열자료가 새로생성됨 = 기존 문자열 변경 못함, 그래서 기존꺼 출력해도 그대로 나옴
# print(number_1)
# print(number_2)


fruits = ['사과', '바나나', '오렌지', '포도', '수박']
print('과일가게에 오신 것을 환영합니다!')
print(f'오늘 판매하는과일{fruits}')
stop = '그만'
apple = 3
banana = 3
orange = 3
grape = 3
waterme = 3

while True:
    print(f'현재재고:사과: {apple}, 바나나: {banana}, 오렌지: {orange}, 포도: {grape}, 수박: {waterme}')
    input_fruits = input('어떤 과일을 구매하시겠습니까? (종료하려면 "그만"을 입력하세요)')
    if input_fruits == '그만':
        break
    elif input_fruits == '사과' and apple >= 0 :
        if apple == 0 :
            print('사과는 모두 품절되었습니다 다른 과일을 골라주세요')
            continue
        apple -= 1
        print(f'사과을(를) 구매하셨습니다! 남은 사과의 재고 :{apple}')
    elif input_fruits == '바나나' and banana >=0 :
        if banana == 0 :
            print('바나나는 모두 품절되었습니다 다른 과일을 골라주세요')
            continue
        banana -= 1
        print(f'바나나을(를) 구매하셨습니다! 남은 바나나의 재고 :{banana}')
    elif input_fruits == '오렌지' and orange >=0 :
        if orange == 0 :
            print('오렌지는 모두 품절되었습니다 다른 과일을 골라주세요')
            continue
        orange -= 1
        print(f'오렌지을(를) 구매하셨습니다! 남은 오렌지의 재고 :{orange}')
    elif input_fruits == '포도' and grape >=0 :
        if grape == 0 :
            print('포도는 모두 품절되었습니다 다른 과일을 골라주세요')
            continue
        grape -= 1
        print(f'포도을(를) 구매하셨습니다! 남은 포도의 재고 :{grape}')
    elif input_fruits == '수박'and waterme >=0 :
        if waterme == 0 :
            print('수박은 모두 품절되었습니다 다른 과일을 골라주세요')
            continue
        grape -= 1
        print(f'수박을(를) 구매하셨습니다! 남은 수박의 재고 :{waterme}')
    elif apple+banana+orange+grape+waterme == 0 :
            print('모든 과일이 다 팔렸습니다. 가게를 종료합니다.')
            break
